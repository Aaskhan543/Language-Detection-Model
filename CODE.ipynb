# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("language.csv")

# %%
data

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

#ek object create karengey hum log
vectorizer = CountVectorizer()

#ek sample test data lengey
data = ["love data science", "love machine learning"]

#ab data transfirm karwa denna hai
vectorized_data = vectorizer.fit_transform(data)

#get vacabulary
print(vectorizer.get_feature_names_out())

#ab reslut ko array coonvert karwa dengey
print(vectorized_data.toarray())

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_csv("language.csv")
data.isnull().sum()

# %%
data['language'].value_counts()

# %%
#ab data ko array me convert kardengey
data.dtypes

# %%
x = np.array(data["Text"])
y = np.array(data["language"])

# %%
print(x)

# %%
data

# %%
cv = CountVectorizer()
x = cv.fit_transform(x)

# %%
X_train,X_test, y_train,y_test = train_test_split(x,y, test_size= 0.33, random_state = 42)

# %%
X_train

# %%
print(X_train)

# %%
model = MultinomialNB()
model.fit(X_train,y_train)

# %%
model.score(X_test,y_test) #check karega accuracy model ki

# %%
user = input("Enter a text")
data = cv.transform([user]).toarray()
output = model.predict(data)
print(output)
